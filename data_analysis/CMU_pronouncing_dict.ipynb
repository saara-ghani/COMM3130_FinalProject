# %% [markdown]
# ## Investigating adding items to `pronouncing` dictionary
#
# * CMU pronouncing dictionary - https://github.com/cmusphinx/cmudict
# * https://cmusphinx.github.io/wiki/tutorialdict/

# %% [markdown]
# ### Setup

# %%
import os
from collections import Counter
import pronouncing
import fuzzywuzzy
import ipa_rhyming
import cmudict

# %%
dictionary = cmudict.dict()

# %%
len(dictionary)
# Out:
# 126052

# %%
dictionary
# Out:
# defaultdict(list,
#             {"'bout": [['B', 'AW1', 'T']],
#              "'cause": [['K', 'AH0', 'Z']],
#              "'course": [['K', 'AO1', 'R', 'S']],
#              "'cuse": [['K', 'Y', 'UW1', 'Z']],
#              "'em": [['AH0', 'M']],
#              "'frisco": [['F', 'R', 'IH1', 'S', 'K', 'OW0']],
#              "'gain": [['G', 'EH1', 'N']],
#              "'kay": [['K', 'EY1']],
#              "'m": [['AH0', 'M']],
#              "'n": [['AH0', 'N']],
#              "'round": [['R', 'AW1', 'N', 'D']],
#              "'s": [['EH1', 'S']],
#              "'til": [['T', 'IH1', 'L']],
#              "'tis": [['T', 'IH1', 'Z']],
#              "'twas": [['T', 'W', 'AH1', 'Z']],
#              'a': [['AH0'], ['EY1']],
#              "a's": [['EY1', 'Z']],
#              'a.': [['EY1']],
#              "a.'s": [['EY1', 'Z']],
#              'a.d.': [['EY2', 'D', 'IY1']],
#              'a.m.': [['EY2', 'EH1', 'M']],
#              'a.s': [['EY1', 'Z']],
# ...
